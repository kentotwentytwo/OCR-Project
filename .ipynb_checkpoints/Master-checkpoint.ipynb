# %% [markdown]
# # Python Project: OCR for Ingredient Labels
#
# ## Project Objective
#
# Create a service that recognizes keywords in a picture (OCR) and searches a database for recognized text. Apply this to reading nutritional labels. The reason for this app is that existing nutritional label reading apps uses databases that may not contain any information on new products or foreign products. This project is coded in Python. *(more details later)*Create a service that recognizes keywords in a picture (OCR) and searches a database for recognized text. Apply this to reading nutritional labels. The reason for this app is that existing nutritional label reading apps uses databases that may not contain any information on new products or foreign products. This project is coded in Python. *(more details later)*

# %% [markdown]
# ## Major Checkpoints & Timeline
#  1. **Installation of code packages** *(Day 1)*
#  2. **Image processing** *(Day 1)*
#  3. **Apply basic OCR to image and bracketing** *(Day 2)*
#  4. **Returning results in a list to be searched** *(Day 2)*
#  5. **Connecting external dataset to be searched using an API** *(Day 3)*
#  6. **Match search text to dataset and returning results** *(Day 4)*

# %% [markdown]
# ## 1 - Installation of code environment

# %% [markdown]
# 1 - **Pillow** - a python imaging library that opens images *(comes with anaconda3)*

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /Users/kt/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (9.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2 - **Opencv** - advanced image manipulation

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/kt/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.17.3 in /Users/kt/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from opencv-python) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 3 - **Tesseract** - OCR prerequisite package

# %%
pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in /Users/kt/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (0.3.10)
# Requirement already satisfied: Pillow>=8.0.0 in /Users/kt/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytesseract) (9.2.0)
# Requirement already satisfied: packaging>=21.3 in /Users/kt/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytesseract) (22.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2a -  Opening Files
#
# ### Opening files with Pillow
# Pillow is for standard image procesing and openCV for more advanced image processing tasks.

# %%
    
#import pillow
from PIL import Image

im_file = "data/page_01.jpg"

#load image into new object 
im = Image.open(im_file)
print (im) 

#// <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=485x402 at 0x7F99842FE460>

#open image in pop-up viewer
im.show()

#save a file
im.save("temp/page_01.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=298x402 at 0x7FCD57F60A90>

# %% [markdown]
# ### Opening files with OpenCV
# OpenCV is used for advanced image handling and processing

# %%
import cv2
# matplotlib is used to show plots, but used to show images inline in this environment
from matplotlib import pyplot as plt

# %% [markdown]
# Specify image directory and read

# %%
img = cv2.imread("data/page_01.jpg")

# %% [markdown]
# <br>
# The function below allows image to show up in the Jupyterlab environment inline using the matplotlib functions <br>
# (https://stackoverflow.com/questions/28816046/%20displaying-different-images-with-actual-size-in-matplotlib-subplot)

# %%
# The function below allows image to show up in the Jupyterlab environment inline using the function display()
#https://stackoverflow.com/questions/28816046/%20displaying-different-images-with-actual-size-in-matplotlib-subplot
def display(im_path):
        
    dpi = 80
    im_data = plt.imread(im_path)
    height, width, depth = im_data.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %% [markdown]
# When using Visual Studio environment, matplot lib is not required and you can display images simply by using openCV functionality:
# ```
# cv2.imshow("original images", img)
#
# #how long to keep preview window open in ms
# cv2.waitKey(2000)
# ```

# %%
display("data/page_01.jpg")

# %% [markdown]
# ## 2b - Basic image processing

# %% [markdown]
# **1. Inverted Images**

# %%
#invert the read 'img' from above
inverted_image = cv2.bitwise_not(img)

#where to save image
cv2.imwrite("temp/inverted.jpg", inverted_image)
# Out:
# True

# %%
#show image
display("temp/inverted.jpg")

# %% [markdown]
# **2. Binarization** <br>
# Convert an image into grayscale, and then to black and white.

# %%
def grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

gray_image = grayscale(img)
cv2.imwrite("temp/gray.jpg", gray_image)

#display function dosen't work for gray / b&w photos b/c of depth loss, so use im.show() to display
im.show("temp/gray.jpg")

# %%
thresh, im_bw = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
cv2.imwrite("temp/bw_image.jpg", im_bw)
# Out:
# True

# %%
#black and white photo
im.show("temp/bw_image.jpg")

# %% [markdown]
# **3. Remove Borders** <br>

# %%
def remove_borders(image):
    contours, heiarchy = cv2.findContours(image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cntsSorted = sorted(contours, key=lambda x:cv2.contourArea(x))
    cnt = cntsSorted[-1]
    x, y, w, h = cv2.boundingRect(cnt)
    crop = image[y:y+h, x:x+w]
    return (crop)

# %%
#removing bordesr only work on grayscale images and not always. So this is not a good method.

no_borders = remove_borders("temp/gray.jpg")
cv2.imwrite("temp/no_borders.jpg", no_borders)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 3
#       1 #removing bordesr only work on grayscale images and not always. So this is not a good method.
# ----> 3 no_borders = remove_borders("temp/gray.jpg")
#       4 cv2.imwrite("temp/no_borders.jpg", no_borders)
#
# Cell In[14], line 2, in remove_borders(image)
#       1 def remove_borders(image):
# ----> 2     contours, heiarchy = cv2.findContours(image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#       3     cntsSorted = sorted(contours, key=lambda x:cv2.contourArea(x))
#       4     cnt = cntsSorted[-1]
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'findContours'
# > Overload resolution failed:
# >  - image is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'image'

# %% [markdown]
# ## 3a - Apply basic OCR

# %% [markdown]
# Pillow is used for image handling and pytesseract is used for OCR

# %%
from PIL import Image
import pytesseract

# %% [markdown]
# <br>Use any file that has high clarity or pre-processed with the steps above.

# %%
#pay attention to the extension, some files are JPG and some are JPEG
img_file = 'data/page_05.JPEG'
img = Image.open(img_file)

# %% [markdown]
# Basic OCR processing without processing.

# %%
ocr_result = pytesseract.image_to_string(img_file)

# %%
print(img_file)
display(img_file)
print('\n')
print(ocr_result)

# %%
print(img_file)
display(img_file)
print('\n')
print(ocr_result)

# %% [markdown]
# ## 3b - Intermediate OCR functions

# %% [markdown]
# When there are multiple columns in the image, we have to use bounding boxes to define separate boundaries of OCR, and then apply the function individually. This creates congrugent and readable OCR results.
#
# To create bounding boxes, the computer vision algo must receive the columns of text in blocks, so that it can draw boxes around the blocks of text to process.
# To create the blocks, we must first blur and dilate the image.

# %% [markdown]
# Import all modules required

# %%
import pytesseract
import cv2
import numpy as np
from PIL import Image

# %% [markdown]
# Import functino for in-line display of images

# %%
from matplotlib import pyplot as plt

# The function below allows image to show up in the Jupyterlab environment inline using the function display()
#https://stackoverflow.com/questions/28816046/%20displaying-different-images-with-actual-size-in-matplotlib-subplot
def display(im_path):
        
    dpi = 80
    im_data = plt.imread(im_path)
    height, width, depth = im_data.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %%
#select image to open
image = cv2.imread("data/page_01.JPG")

# %%
#select ROI function
roi = cv2.selectROI(image)

#print rectangle points of selected roi
print(roi)

#Crop selected roi from raw image
roi_cropped = image[int(roi[1]):int(roi[1]+roi[3]), int(roi[0]):int(roi[0]+roi[2])]

#command to open window
cv2.namedWindow('display1')

#show cropped image
cv2.imshow("ROI", roi_cropped)
cv2.imwrite("temp/crop.jpg",roi_cropped)

#close windows (command specific to mac)
cv2.destroyAllWindows()
for i in range (1,5):
    cv2.waitKey(1)
# Out:
# (8, 7, 277, 374)

# %% [markdown]
# Bounding box selected:

# %%
display("temp/crop.jpg")

# %% [markdown]
# ### Perform OCR on the ROI:

# %%
ocr_result = pytesseract.image_to_string(roi_cropped)
print(ocr_result)
# Out:
# INGREDIENTS: MILK, CREAM, SUGAR, CORN
# ‘SYRUP, DESSERT SOLIDS (WHEY, WHEY SOLIDS,
# NONFAT DRY MILK, AND EDIBLE SALTS
# (SODIUM CARBONATE, DI-POTASSIUM
# PHOSPHATE AND SODIUM CITRATE)), COOKIE
# DOUGH (WHEAT FLOUR, SUGAR, BUTTER,
# BROWN SUGAR, PASTEURIZED EGGS, SALT,
# BAKING SODA, NATURAL FLAVOR, CARAMEL
# COLOR), COOKIE DOUGH BASE (HIGH
# FRUCTOSE CORN SYRUP, BROWN SUGAR,
# WATER, MOLASSES, NATURAL FLAVORS, AND
# SALT), CHOCOLATE CHIPS (SUGAR, CHOCOLATE
# LIQUOR, COCOA BUTTER, SOY LECITHIN (AN
# EMULSIFIER), AND VANILLA), STABILIZER
# (MONO & DIGLYCERIDES, CELLULOSE GUM,
# GUAR GUM, LOCUST BEAN GUM,
# POLYSORBATE 80, CARRAGEENAN, DISODIUM
# PHOSPHATE, CALCIUM SULFATE), NATURAL
# AND/OR ARTIFICIAL FLAVORS AND ANNATTO.

# %% [markdown]
# Split the string at commas

# %%
print(type(ocr_result))
print(ocr_result.split(","))
# Out:
# <class 'str'>
# ['INGREDIENTS: MILK', ' CREAM', ' SUGAR', ' CORN\n‘SYRUP', ' DESSERT SOLIDS (WHEY', ' WHEY SOLIDS', '\nNONFAT DRY MILK', ' AND EDIBLE SALTS\n(SODIUM CARBONATE', ' DI-POTASSIUM\nPHOSPHATE AND SODIUM CITRATE))', ' COOKIE\nDOUGH (WHEAT FLOUR', ' SUGAR', ' BUTTER', '\nBROWN SUGAR', ' PASTEURIZED EGGS', ' SALT', '\nBAKING SODA', ' NATURAL FLAVOR', ' CARAMEL\nCOLOR)', ' COOKIE DOUGH BASE (HIGH\nFRUCTOSE CORN SYRUP', ' BROWN SUGAR', '\nWATER', ' MOLASSES', ' NATURAL FLAVORS', ' AND\nSALT)', ' CHOCOLATE CHIPS (SUGAR', ' CHOCOLATE\nLIQUOR', ' COCOA BUTTER', ' SOY LECITHIN (AN\nEMULSIFIER)', ' AND VANILLA)', ' STABILIZER\n(MONO & DIGLYCERIDES', ' CELLULOSE GUM', '\nGUAR GUM', ' LOCUST BEAN GUM', '\nPOLYSORBATE 80', ' CARRAGEENAN', ' DISODIUM\nPHOSPHATE', ' CALCIUM SULFATE)', ' NATURAL\nAND/OR ARTIFICIAL FLAVORS AND ANNATTO.\n']

# %% [markdown]
# Save ocr_result into a list of indidvidual ingredients in the variable 'results':

# %%
results= []
for item in ocr_result.split(","):
    results.append(item.strip())
print(results[1:])
# Out:
# ['CREAM', 'SUGAR', 'CORN\n‘SYRUP', 'DESSERT SOLIDS (WHEY', 'WHEY SOLIDS', 'NONFAT DRY MILK', 'AND EDIBLE SALTS\n(SODIUM CARBONATE', 'DI-POTASSIUM\nPHOSPHATE AND SODIUM CITRATE))', 'COOKIE\nDOUGH (WHEAT FLOUR', 'SUGAR', 'BUTTER', 'BROWN SUGAR', 'PASTEURIZED EGGS', 'SALT', 'BAKING SODA', 'NATURAL FLAVOR', 'CARAMEL\nCOLOR)', 'COOKIE DOUGH BASE (HIGH\nFRUCTOSE CORN SYRUP', 'BROWN SUGAR', 'WATER', 'MOLASSES', 'NATURAL FLAVORS', 'AND\nSALT)', 'CHOCOLATE CHIPS (SUGAR', 'CHOCOLATE\nLIQUOR', 'COCOA BUTTER', 'SOY LECITHIN (AN\nEMULSIFIER)', 'AND VANILLA)', 'STABILIZER\n(MONO & DIGLYCERIDES', 'CELLULOSE GUM', 'GUAR GUM', 'LOCUST BEAN GUM', 'POLYSORBATE 80', 'CARRAGEENAN', 'DISODIUM\nPHOSPHATE', 'CALCIUM SULFATE)', 'NATURAL\nAND/OR ARTIFICIAL FLAVORS AND ANNATTO.']

# %%
#create new list to place cleaned items
clean_results = []
clean_results_no_filter = []

for item in results:
    if item.find("\n") >=0 or item.find("(") >= 0 or item.find(")") >= 0 or item.find("‘") >= 0 or item.find("/") >= 0:
        new_item = item.replace("\n","_",5)
        
        new_item = item.replace(" ", "_",5)
 
        new_item = item.replace("(","",5)

        new_item = item.replace(")","",5)         

        new_item = item.replace("‘","",5)
        
        new_item = item.replace(",","",5)


        new_item = item.replace("/","",5)


        new_item = item.replace(",","",5)


        new_item = item.replace(" ","_",5)
        
        clean_results.append(new_item)
    else:
        clean_results_no_filter.append(item)
        

print(sorted(clean_results))
print('\n')
print(sorted(clean_results_no_filter))
# Out:
# ['AND\nSALT)', 'AND_EDIBLE_SALTS\n(SODIUM_CARBONATE', 'AND_VANILLA)', 'CALCIUM_SULFATE)', 'CARAMEL\nCOLOR)', 'CHOCOLATE\nLIQUOR', 'CHOCOLATE_CHIPS_(SUGAR', 'COOKIE\nDOUGH_(WHEAT_FLOUR', 'COOKIE_DOUGH_BASE_(HIGH\nFRUCTOSE_CORN_SYRUP', 'CORN\n‘SYRUP', 'DESSERT_SOLIDS_(WHEY', 'DI-POTASSIUM\nPHOSPHATE_AND_SODIUM_CITRATE))', 'DISODIUM\nPHOSPHATE', 'NATURAL\nAND/OR_ARTIFICIAL_FLAVORS_AND_ANNATTO.', 'SOY_LECITHIN_(AN\nEMULSIFIER)', 'STABILIZER\n(MONO_&_DIGLYCERIDES']
#
#
# ['BAKING SODA', 'BROWN SUGAR', 'BROWN SUGAR', 'BUTTER', 'CARRAGEENAN', 'CELLULOSE GUM', 'COCOA BUTTER', 'CREAM', 'GUAR GUM', 'INGREDIENTS: MILK', 'LOCUST BEAN GUM', 'MOLASSES', 'NATURAL FLAVOR', 'NATURAL FLAVORS', 'NONFAT DRY MILK', 'PASTEURIZED EGGS', 'POLYSORBATE 80', 'SALT', 'SUGAR', 'SUGAR', 'WATER', 'WHEY SOLIDS']

# %% [markdown]
# There are duplicates in the result eg.  butter, corn, whey. Creating a set will remove the duplicates.

# %%
ingredients = set(clean2_results)
print(type(ingredients))
for item in ingredients:
    print(item)
# Out:
# <class 'set'>
# NATURAL AND/OR ARTIFICIAL FLAVORS AND ANNATTO.
# CALCIUM SULFATE
# CORN ‘SYRUP
# AND VANILLA
# NATURAL_FLAVORS
# SUGAR
# CELLULOSE_GUM
# DISODIUM PHOSPHATE
# INGREDIENTS:_MILK
# CREAM
# GUAR_GUM
# BUTTER
# DI-POTASSIUM PHOSPHATE AND SODIUM CITRATE))
# COOKIE DOUGH (WHEAT FLOUR
# PASTEURIZED_EGGS
# CARRAGEENAN
# LOCUST_BEAN_GUM
# WHEY_SOLIDS
# BAKING_SODA
# AND EDIBLE SALTS (SODIUM CARBONATE
# MOLASSES
# POLYSORBATE_80
# NATURAL_FLAVOR
# CHOCOLATE CHIPS SUGAR
# BROWN_SUGAR
# SOY LECITHIN (AN EMULSIFIER)
# COOKIE DOUGH BASE (HIGH FRUCTOSE CORN SYRUP
# STABILIZER (MONO & DIGLYCERIDES
# NONFAT_DRY_MILK
# AND SALT)
# SALT
# DESSERT SOLIDS WHEY
# WATER
# CHOCOLATE LIQUOR
# CARAMEL COLOR)
# COCOA_BUTTER

# %% [markdown]
# We do not need the ingredients list to be 100% perfect eg. 80, AN etc. since it is a back-end dataset which would be used to match a database of ingredients. If a word does not match the database, it will simply be ignored.

# %% [markdown]
# Next we generate a predefined link to search wikipedia based on the ingredient name

# %%
def print_link (ingredient):
  return "https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom={}&gaplimit=5".format(ingredient)

print(print_link("sodium"))
# Out:
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=sodium&gaplimit=5

# %%
for item in ingredients:
    print(item)
    print(print_link(item),'\n')
# Out:
# NATURAL AND/OR ARTIFICIAL FLAVORS AND ANNATTO.
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=NATURAL AND/OR ARTIFICIAL FLAVORS AND ANNATTO.&gaplimit=5
#
# CALCIUM SULFATE
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=CALCIUM SULFATE&gaplimit=5
#
# CORN ‘SYRUP
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=CORN ‘SYRUP&gaplimit=5
#
# AND VANILLA
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=AND VANILLA&gaplimit=5
#
# GUAR GUM
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=GUAR GUM&gaplimit=5
#
# SUGAR
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=SUGAR&gaplimit=5
#
# LOCUST BEAN GUM
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=LOCUST BEAN GUM&gaplimit=5
#
# CELLULOSE GUM
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=CELLULOSE GUM&gaplimit=5
#
# DISODIUM PHOSPHATE
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=DISODIUM PHOSPHATE&gaplimit=5
#
# CREAM
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=CREAM&gaplimit=5
#
# WHEY SOLIDS
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=WHEY SOLIDS&gaplimit=5
#
# BUTTER
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=BUTTER&gaplimit=5
#
# DI-POTASSIUM PHOSPHATE AND SODIUM CITRATE))
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=DI-POTASSIUM PHOSPHATE AND SODIUM CITRATE))&gaplimit=5
#
# COOKIE DOUGH (WHEAT FLOUR
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=COOKIE DOUGH (WHEAT FLOUR&gaplimit=5
#
# CARRAGEENAN
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=CARRAGEENAN&gaplimit=5
#
# NATURAL FLAVOR
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=NATURAL FLAVOR&gaplimit=5
#
# PASTEURIZED EGGS
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=PASTEURIZED EGGS&gaplimit=5
#
# BAKING SODA
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=BAKING SODA&gaplimit=5
#
# NONFAT DRY MILK
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=NONFAT DRY MILK&gaplimit=5
#
# NATURAL FLAVORS
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=NATURAL FLAVORS&gaplimit=5
#
# AND EDIBLE SALTS (SODIUM CARBONATE
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=AND EDIBLE SALTS (SODIUM CARBONATE&gaplimit=5
#
# MOLASSES
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=MOLASSES&gaplimit=5
#
# POLYSORBATE 80
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=POLYSORBATE 80&gaplimit=5
#
# CHOCOLATE CHIPS SUGAR
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=CHOCOLATE CHIPS SUGAR&gaplimit=5
#
# SOY LECITHIN (AN EMULSIFIER)
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=SOY LECITHIN (AN EMULSIFIER)&gaplimit=5
#
# COOKIE DOUGH BASE (HIGH FRUCTOSE CORN SYRUP
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=COOKIE DOUGH BASE (HIGH FRUCTOSE CORN SYRUP&gaplimit=5
#
# STABILIZER (MONO & DIGLYCERIDES
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=STABILIZER (MONO & DIGLYCERIDES&gaplimit=5
#
# INGREDIENTS: MILK
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=INGREDIENTS: MILK&gaplimit=5
#
# AND SALT)
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=AND SALT)&gaplimit=5
#
# BROWN SUGAR
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=BROWN SUGAR&gaplimit=5
#
# SALT
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=SALT&gaplimit=5
#
# DESSERT SOLIDS WHEY
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=DESSERT SOLIDS WHEY&gaplimit=5
#
# COCOA BUTTER
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=COCOA BUTTER&gaplimit=5
#
# WATER
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=WATER&gaplimit=5
#
# CHOCOLATE LIQUOR
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=CHOCOLATE LIQUOR&gaplimit=5
#
# CARAMEL COLOR)
# https://en.wikipedia.org/w/api.php?action=query&format=json&prop=info&generator=allpages&inprop=url&gapfrom=CARAMEL COLOR)&gaplimit=5

# %%
import requests
 
    
query = 'CALCIUM'
 
url = 'https://en.wikipedia.org/w/api.php'
params = {
            'action':'query',
            'format':'json',
            'list':'search',
            'utf8':1,
            'srsearch':query
        }
 
data = requests.get(url, params=params).json()

# %%
print(data)
# Out:
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 16214}, 'search': [{'ns': 0, 'title': 'Calcium', 'pageid': 5668, 'size': 47565, 'wordcount': 5777, 'snippet': '<span class="searchmatch">Calcium</span> is a chemical element with the symbol Ca and atomic number 20. As an alkaline earth metal, <span class="searchmatch">calcium</span> is a reactive metal that forms a dark oxide-nitride', 'timestamp': '2022-11-26T13:58:20Z'}, {'ns': 0, 'title': 'Calcium oxide', 'pageid': 147536, 'size': 20379, 'wordcount': 2010, 'snippet': '<span class="searchmatch">Calcium</span> oxide (CaO), commonly known as quicklime or burnt lime, is a widely used chemical compound. It is a white, caustic, alkaline, crystalline solid', 'timestamp': '2023-02-02T14:05:07Z'}, {'ns': 0, 'title': 'Calcium carbonate', 'pageid': 44731, 'size': 72036, 'wordcount': 6973, 'snippet': '<span class="searchmatch">Calcium</span> carbonate is a chemical compound with the chemical formula CaCO3. It is a common substance found in rocks as the minerals calcite and aragonite', 'timestamp': '2023-01-19T15:20:12Z'}, {'ns': 0, 'title': 'Calcium channel blocker', 'pageid': 252559, 'size': 29188, 'wordcount': 3233, 'snippet': '<span class="searchmatch">Calcium</span> channel blockers (CCB), <span class="searchmatch">calcium</span> channel antagonists or <span class="searchmatch">calcium</span> antagonists are a group of medications that disrupt the movement of <span class="searchmatch">calcium</span> (Ca2+', 'timestamp': '2022-10-11T14:35:11Z'}, {'ns': 0, 'title': 'Calcium hydroxide', 'pageid': 386748, 'size': 21264, 'wordcount': 2004, 'snippet': '<span class="searchmatch">Calcium</span> hydroxide (traditionally called slaked lime) is an inorganic compound with the chemical formula Ca(OH)2. It is a colorless crystal or white powder', 'timestamp': '2023-01-26T20:04:49Z'}, {'ns': 0, 'title': 'Calcium chloride', 'pageid': 349627, 'size': 26112, 'wordcount': 1965, 'snippet': '<span class="searchmatch">Calcium</span> chloride is an inorganic compound, a salt with the chemical formula CaCl2. It is a white crystalline solid at room temperature, and it is highly', 'timestamp': '2023-01-26T20:46:55Z'}, {'ns': 0, 'title': 'Calcium carbide', 'pageid': 242643, 'size': 17317, 'wordcount': 1647, 'snippet': '<span class="searchmatch">Calcium</span> carbide, also known as <span class="searchmatch">calcium</span> acetylide, is a chemical compound with the chemical formula of CaC2. Its main use industrially is in the production', 'timestamp': '2023-02-05T13:56:06Z'}, {'ns': 0, 'title': 'Calcium sulfate', 'pageid': 595183, 'size': 22012, 'wordcount': 2218, 'snippet': '<span class="searchmatch">Calcium</span> sulfate (or <span class="searchmatch">calcium</span> sulphate) is the inorganic compound with the formula CaSO4 and related hydrates. In the form of γ-anhydrite (the anhydrous', 'timestamp': '2022-12-19T22:13:55Z'}, {'ns': 0, 'title': 'Calcium channel', 'pageid': 1513441, 'size': 8402, 'wordcount': 505, 'snippet': 'A <span class="searchmatch">calcium</span> channel is an ion channel which shows selective permeability to <span class="searchmatch">calcium</span> ions. It is sometimes synonymous with voltage-gated <span class="searchmatch">calcium</span> channel', 'timestamp': '2022-10-12T09:37:17Z'}, {'ns': 0, 'title': 'Calcium oxalate', 'pageid': 229254, 'size': 15356, 'wordcount': 1413, 'snippet': '<span class="searchmatch">Calcium</span> oxalate (in archaic terminology, oxalate of lime) is a <span class="searchmatch">calcium</span> salt of oxalic acid with the chemical formula CaC2O4. It forms hydrates CaC2O4·nH2O', 'timestamp': '2023-01-22T16:42:06Z'}]}}

# %% [markdown]
# ## FAQ:
#
# ### 1.  Error: openCV, pytesseract or pillow not found:
# * make sure you run pip install for the modules in the kernal of this notebook
# * check the kernel source exists in the app's sidebar
#
# ### 2.  Error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'boundingRect'
# > Overload resolution failed:
# >  - array is not a numerical tuple
# >  - Expected Ptr<cv::UMat> for argument 'array'error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'boundingRect'
# > Overload resolution failed:
# >  - array is not a numerical tuple
# >  - Expected Ptr<cv::UMat> for argument 'array'
#
# > **cv2.findContours** outputs 2 values: contours, hierarchy. Ensure you are setting the correct number of inputs (2).
#     I added a second input "hierarchy" in the second line and resolved problem that "array is not a numerical tuple"; program was asking for two values.
#     > ``` cnts = sorted(cnts, key=lambda x: cv2.boundingRect(x)[0]) cnts = sorted(cnts, key=lambda x: cv2.boundingRect(x)[0]) ``` to <br>
#     > ```cnts, hierarchy = sorted(cnts, key=lambda x: cv2.boundingRect(x)[0]) cnts = sorted(cnts, key=lambda x: cv2.boundingRect(x)[0])```
#
# ### 3.  Things are not working after restarting kernal
# * re-run code blocks for importing PIL, pytessearct, cv2, pyplot
#
# ### 4. In-line images are not loading properly or not refreshing after changing code
# * restart kernal, re-import modules and try again
#
# ### 5. Window stuck or not responding
# * restart kernal
# * if image is too large, performance will be slow, reduce image size before selecting ROI
